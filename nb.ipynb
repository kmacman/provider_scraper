# %%
import requests
from rich import print
import pandas as pd
from main import get_provider_index, get_provider_details, get_all_providers

# %%
get_provider_index()

# %%
get_provider_details(209033)
# Out:
# {'provider_id': 209033,
#  'first': 'Stephen',
#  'middle': 'J.',
#  'last': 'Paolella',
#  'dept': 'Berkshire Facial Surgery, Inc.'}

# %%
all_providers = get_all_providers()
# Out:
# {'provider_id': '209033', 'first': 'Stephen', 'middle': 'J.', 'last': 'Paolella', 'dept': 'Berkshire Facial Surgery, Inc.'}
# {'provider_id': '209087', 'first': 'Meagan', 'middle': 'E.', 'last': 'Hudak', 'dept': 'Holyoke Pediatric Associates, LLP'}
# {'provider_id': '3105207', 'first': 'Mohamed', 'middle': 'Ehab', 'last': 'Ramadan', 'dept': 'Baystate Pain Management Center'}
# {'provider_id': '759071', 'first': 'Megan', 'middle': 'C.', 'last': 'Gallagher', 'dept': 'Baystate Infectious Disease'}
# {'provider_id': '207773', 'first': 'Stephen', 'middle': 'G.', 'last': 'Mueller', 'dept': 'Baystate Behavioral Health - Adult Psychiatric Treatment Unit'}
# {'provider_id': '207641', 'first': 'Saborna', 'middle': None, 'last': 'Das', 'dept': 'BMP Hospital Medicine'}
# {'provider_id': '1194110', 'first': 'Meghan', 'middle': 'Marie', 'last': 'Provost', 'dept': 'Baystate Longmeadow Primary Care'}
# ...
