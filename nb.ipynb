# %%
import requests
from rich import print
from main import get_provider_index

# %%
get_provider_index()
# Out:
# ['209033',
#  '209087',
#  '3105207',
#  '759071',
#  '207773',
#  '207641',
#  '1194110',
#  '754597',
#  '2174706',
#  '611103',
#  '208228',
#  '728871',
#  '209419',
#  '3155331',
#  '2304914',
#  '2440905',
#  '1208571',
#  '1135229',
#  '209249',
#  '3015157',
#  '208743',
#  '231510',
#  '3015156',
#  '2594124',
#  '1889732',
#  '207261',
#  '207785',
#  '820798',
#  '229616',
#  '208222',
#  '207595',
#  '207826',
#  '209176',
#  '208711',
#  '1535278',
#  '207483',
#  '207396',
#  '354187',
#  '208392',
#  '207241',
#  '2304905',
#  '2591287',
#  '207925',
#  '2364544',
#  '207890',
#  '208696',
#  '1815339',
#  '2583516',
#  '207656',
#  '208401',
#  '207802',
#  '2631356',
#  '2013871',
#  '1163477',
#  '207794',
#  '900756',
#  '357077',
#  '208407',
#  '3094688',
#  '207179',
#  '209059',
#  '367191',
#  '207455',
#  '357728',
#  '208923',
#  '1161670',
#  '208966',
#  '3104679',
#  '208995',
#  '209267',
#  '3015155',
#  '2563481',
#  '712352',
#  '3143399',
# ...

# %%
resp = requests.get("https://api.kyruus.com/v9/baystate/providers/2583520?context=baystate_pmc&access_token=4f9dbda891b34697b8d11de25d02323f")
resp.json()['provider']['departments']
# Out:
# ['Baystate Emergency Medicine']
